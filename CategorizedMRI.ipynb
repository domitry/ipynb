# %% [markdown]
# # The introduction of CategorizedMRI

# %%
# %matplotlib inline
from ipysurfer.mri import MRI, CategorizedMRI

# %%
cat = CategorizedMRI.from_mgz("/home/naoki/data/brain/aparc.a2009s+aseg.mgz", "/home/naoki/data/brain/ColorLUT.txt")

# %%
cat.show(100)

# %%
cat.show(30)

# %%
cat.plot()
# Out:
# <html>
#   <head>
#     <style type="text/css">
#      .webgl-container{
#        display:table;
#      }
#
#      .webgl{
#        display:table-cell;
#      }
#
#      .control{
#        padding: 10px;
#        display:table-cell;
#        vertical-align:top;
#      }
#
#      .row{
#        display: table-row;
#      }
#
#      .content{
#        padding: 5px;
#        display:table-cell;
#        vertical-align:middle;
#      }
#
#      .control_label{
#        width: 6em;
#        display:table-cell;
#        vertical-align:middle;
#      }
#     </style>
#     <script type="text/javascript">
#      (function(){
#        require.config({
#          paths: {
#            Three: "https://cdnjs.cloudflare.com/ajax/libs/three.js/r49/Three.min",
#            underscore: "http://underscorejs.org/underscore"
#          },
#          shim: {
#            exports: {
#              Three: "THREE"
#            }
#          }
#        });
#
# ...
